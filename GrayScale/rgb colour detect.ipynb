# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import cv2
import math

# %%
rgb_weights = [0.2989, 0.5870, 0.1140]
imagex = matplotlib.image.imread("C:/Users/avish/Desktop/All/.sliit/SLIIT Y3S1/Design Project - I - EC3061/data/New folder/tomato1.jpg")

# %%
print("Data type", type(imagex))
# Out:
# Data type <class 'numpy.ndarray'>

# %%
grayscale_image = np.dot(imagex[...,:3], rgb_weights)
dummy=np.dot(imagex[...,:3], rgb_weights)
#grayscale_image=(grayscale_image//1)

# %%
plt.imshow(grayscale_image, cmap=plt.get_cmap("gray"))
plt.show()

# %%
fig = plt.gcf()
size = fig.get_size_inches()*fig.dpi
print(size)
print(fig.get_size_inches)
print(fig.dpi) #resolution in dots per inch.
print(grayscale_image.shape) #dimensions of the array
# Out:
# [432. 288.]
# <bound method Figure.get_size_inches of <Figure size 432x288 with 0 Axes>>
# 72.0
# (580, 1000)

# %%
print(grayscale_image.shape)
print(imagex.shape)
# Out:
# (580, 1000)
# (580, 1000, 3)

# %%
print(grayscale_image.shape)
# Out:
# (580, 1000)

# %%
#lower_red = [0,150,50]---------->66
#upper_red = [10,255,255]-------->173

#     COL  COL  COL
#ROW
#ROW
#ROW

print(grayscale_image[1,90])
ROW=len(grayscale_image)
COL=len(grayscale_image[0])
print(ROW)
print(COL)
# Out:
# 250.18929999999997
# 580
# 1000

# %%
#print(grayscale_image)
#arr=grayscale_image[0,0]
#print(arr)
tup1 = ("173","66")
print( tup1[0] )

for i in range (ROW):
    for j in range (COL):
        if(((grayscale_image[i,j])>200)and((grayscale_image[i,j])>66)):
            grayscale_image[i,j]=((grayscale_image[i,j])/(grayscale_image[i,j]))*255
        else:
            grayscale_image[i,j]=(grayscale_image[i,j])*0
# Out:
# 173

# %%
cv2.imwrite('C:/Users/avish/Desktop/All/.sliit/SLIIT Y3S1/Design Project - I - EC3061/out/ggaaq.jpg',grayscale_image)
# Out:
# True
